# %% [markdown]
# # Lab-20 :

# %% [markdown]
# ## 1. Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
# 1. Given data [(x,y)] fill the plane to visualize
x = [2, 3, 4, 8, 3, 6]
y = [8, 9, 2, 4, 6, 7]

plt.fill_between(x, y)
plt.show()
